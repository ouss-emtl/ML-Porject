# %%
import numpy as np
import matplotlib.pyplot
import pandas as pd

# %%
# Lecture du fichier excel

data=pd.read_excel(r"C:\Users\Rudolf\desktop\Free stuffs\MachineLearning\titanic3.xls")

# %%
# taille

shape=data.shape

# %%
# voir les premières lignes

head=data.head

# %%
head
# Out:
# <bound method NDFrame.head of       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# ...

# %%
# Eliminer les informations  inutiles

data=data.drop(['name','sibsp','parch','ticket','fare','cabin','embarked','boat','body','home.dest'],axis=1)
data
# Out:
#       pclass  survived     sex      age
# 0          1         1  female  29.0000
# 1          1         1    male   0.9167
# 2          1         0  female   2.0000
# 3          1         0    male  30.0000
# 4          1         0  female  25.0000
# 5          1         1    male  48.0000
# 6          1         1  female  63.0000
# 7          1         0    male  39.0000
# 8          1         1  female  53.0000
# 9          1         0    male  71.0000
# 10         1         0    male  47.0000
# 11         1         1  female  18.0000
# 12         1         1  female  24.0000
# 13         1         1  female  26.0000
# 14         1         1    male  80.0000
# 15         1         0    male      NaN
# 16         1         0    male  24.0000
# 17         1         1  female  50.0000
# 18         1         1  female  32.0000
# 19         1         0    male  36.0000
# 20         1         1    male  37.0000
# 21         1         1  female  47.0000
# ...

# %%
# Avoir les stats

data.describe()
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1046.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    14.413500
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    21.000000
# 50%       3.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
# Eliminer les lignes ayant les données manquantes

data=data.dropna(axis=0)

# %%
data
# Out:
#       pclass  survived     sex      age
# 0          1         1  female  29.0000
# 1          1         1    male   0.9167
# 2          1         0  female   2.0000
# 3          1         0    male  30.0000
# 4          1         0  female  25.0000
# 5          1         1    male  48.0000
# 6          1         1  female  63.0000
# 7          1         0    male  39.0000
# 8          1         1  female  53.0000
# 9          1         0    male  71.0000
# 10         1         0    male  47.0000
# 11         1         1  female  18.0000
# 12         1         1  female  24.0000
# 13         1         1  female  26.0000
# 14         1         1    male  80.0000
# 16         1         0    male  24.0000
# 17         1         1  female  50.0000
# 18         1         1  female  32.0000
# 19         1         0    male  36.0000
# 20         1         1    male  37.0000
# 21         1         1  female  47.0000
# 22         1         1    male  26.0000
# ...

# %%
data.shape
# Out:
# (1046, 4)

# %%
# Calcul de moyenne et autres (groupement)
data.groupby(['sex','pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.962406  37.037594
#        2       0.893204  27.499191
#        3       0.473684  22.185307
# male   1       0.350993  41.029250
#        2       0.145570  30.815401
#        3       0.169054  25.962273

# %%
# Series
data['sex']
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
# 10        male
# 11      female
# 12      female
# 13      female
# 14        male
# 16        male
# 17      female
# 18      female
# 19        male
# 20        male
# 21      female
# 22        male
# 23      female
# 24      female
# 25        male
# 26        male
# 27      female
# 28      female
# 29        male
# 30        male
#          ...
# 1269      male
# 1270      male
# 1271      male
# 1272      male
# 1273    female
# 1274      male
# 1275      male
# 1276    female
# 1277      male
# 1278      male
# 1279    female
# 1280      male
# 1281      male
# 1285      male
# 1286    female
# 1287      male
# 1288      male
# 1289      male
# 1290    female
# 1294      male
# 1295      male
# 1296      male
# 1298      male
# 1299      male
# 1300    female
# 1301      male
# 1304    female
# ...

# %%
# modification d'index

#data=data.set_index('name')

# %%
# Appliquer un masque
data[data['age']<18]
# Out:
#       pclass  survived     sex      age
# 1          1         1    male   0.9167
# 2          1         0  female   2.0000
# 53         1         0    male  17.0000
# 54         1         1    male  11.0000
# 55         1         1  female  14.0000
# 92         1         1  female  17.0000
# 94         1         1    male   4.0000
# 159        1         1  female  16.0000
# 187        1         1  female  16.0000
# 193        1         1  female  15.0000
# 195        1         1  female  16.0000
# 229        1         1  female  17.0000
# 249        1         1    male  13.0000
# 273        1         1    male   6.0000
# 295        1         1    male  17.0000
# 339        2         1    male   1.0000
# 340        2         1  female   4.0000
# 341        2         1  female  12.0000
# 350        2         1  female  15.0000
# 359        2         1    male   0.8333
# 377        2         1  female   8.0000
# 385        2         1    male   8.0000
# ...

# %%
# pour déterminer les index
data.iloc[0:10,0:2]
# Out:
#    pclass  survived
# 0       1         1
# 1       1         1
# 2       1         0
# 3       1         0
# 4       1         0
# 5       1         1
# 6       1         1
# 7       1         0
# 8       1         1
# 9       1         0

# %%
# localisation par colonne
data.loc[0:50,['age','sex']]
# Out:
#         age     sex
# 0   29.0000  female
# 1    0.9167    male
# 2    2.0000  female
# 3   30.0000    male
# 4   25.0000  female
# 5   48.0000    male
# 6   63.0000  female
# 7   39.0000    male
# 8   53.0000  female
# 9   71.0000    male
# 10  47.0000    male
# 11  18.0000  female
# 12  24.0000  female
# 13  26.0000  female
# 14  80.0000    male
# 16  24.0000    male
# 17  50.0000  female
# 18  32.0000  female
# 19  36.0000    male
# 20  37.0000    male
# 21  47.0000  female
# 22  26.0000    male
# 23  42.0000  female
# 24  29.0000  female
# 25  25.0000    male
# 26  25.0000    male
# 27  19.0000  female
# 28  35.0000  female
# 29  28.0000    male
# 30  45.0000    male
# 31  40.0000    male
# 32  30.0000  female
# 33  58.0000  female
# 34  42.0000    male
# 35  45.0000  female
# 36  22.0000  female
# 38  41.0000    male
# 39  48.0000    male
# 41  44.0000  female
# 42  59.0000  female
# 43  60.0000  female
# 44  41.0000  female
# 45  45.0000    male
# 47  42.0000    male
# ...
