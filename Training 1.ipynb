# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
filepath="kc_house_data.csv"
house_data=pd.read_csv(filepath)

# %%
house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#sns.pairplot(house_data)

# %%
#sns.scatterplot(x='sqft_living',y='price',data=house_data)

# %%
X=house_data.drop(['price','id','date','long','view','waterfront'],axis=1)
y=house_data['price']

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  grade  \
# 0         3       1.00         1180      5650     1.0          3      7
# 1         3       2.25         2570      7242     2.0          3      7
# 2         2       1.00          770     10000     1.0          3      6
# 3         4       3.00         1960      5000     1.0          5      7
# 4         3       2.00         1680      8080     1.0          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0        1180              0      1955             0    98178  47.5112
# 1        2170            400      1951          1991    98125  47.7210
# 2         770              0      1933             0    98028  47.7379
# 3        1050            910      1965             0    98136  47.5208
# 4        1680              0      1987             0    98074  47.6168
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# ...

# %%
from sklearn.feature_selection import SelectKBest, chi2,f_regression

# %%
selector=SelectKBest(chi2,k=14)
selector.fit_transform(X,y)
selector.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True])

# %%
X=X[np.array(X.columns[selector.get_support()])]

# %%
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import SGDClassifier,Ridge,Lasso
from sklearn.preprocessing import StandardScaler,PolynomialFeatures,RobustScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVC,LinearSVC

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

# %%
model=make_pipeline(SimpleImputer(strategy='median'),RobustScaler(),Lasso(alpha=10,max_iter=100000))
#model=make_pipeline(SimpleImputer(),StandardScaler(),Lasso(alpha=0.2,max_iter=10000))
#model=Ridge(alpha=0.01)

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('robustscaler', RobustScaler()),
#                 ('lasso', Lasso(alpha=10, max_iter=100000))])

# %%
model.score(X_test,y_test)
# Out:
# 0.6189551668646447

# %%
from sklearn.model_selection import learning_curve

# %%
# N,train_score,val_score=learning_curve(model,X_train,y_train,train_sizes=np.linspace(0.1,1.0,50),cv=4)
# print(N)
# plt.plot(N,train_score.mean(axis=1),label='train')
# plt.plot(N,val_score.mean(axis=1),label='validation')
# plt.xlabel('train sizes')
# plt.legend()
# plt.show()

# %%
params={'fit_intercept':['True','False'],'alpha':[0.8,1,2,3,4,5],'selection':['cyclic', 'random'],'max_iter':[1000,5000,10000,100000]}
grid=GridSearchCV(model,param_grid=params, cv=4)

grid.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-b587bdaf0ac2> in <module>
#       2 grid=GridSearchCV(model,param_grid=params, cv=4)
#       3
# ----> 4 grid.fit(X_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ...

# %%
grid.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-fb6b380b5a97> in <module>
# ----> 1 grid.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
grid.best_score_
# Out:
# 0.5698432391179601
